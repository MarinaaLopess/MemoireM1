# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python3 -m spacy download fr_core_news_lg
# Out:
# Collecting fr-core-news-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_lg-3.8.0/fr_core_news_lg-3.8.0-py3-none-any.whl (571.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.8/571.8 MB 2.2 MB/s eta 0:00:00
# Installing collected packages: fr-core-news-lg
# Successfully installed fr-core-news-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import os
import json
import spacy
from tqdm import tqdm


nlp = spacy.load('fr_core_news_lg')

base_path = "/content/drive/MyDrive/Poemes/"
dic = {}

entites_par_auteur = {}
tokens_par_auteur = {}

for auteur in tqdm(os.listdir(base_path), desc="Auteurs", unit="auteur"):
    auteur_path = os.path.join(base_path, auteur)

    if os.path.isdir(auteur_path):
        entites_par_auteur[auteur] = 0
        tokens_par_auteur[auteur] = 0

        for poeme in tqdm(os.listdir(auteur_path), desc=f"Poèmes de {auteur}", unit="poème", leave=False):
            if poeme.endswith(".txt"):
                file_path = os.path.join(auteur_path, poeme)

                with open(file_path, "r", encoding="utf-8") as f:
                    contenu = f.read()

                doc = nlp(contenu)

                nb_tokens = len([token for token in doc if not token.is_space])
                nb_entites = len(doc.ents)

                tokens_par_auteur[auteur] += nb_tokens
                entites_par_auteur[auteur] += nb_entites

                dic[poeme] = {
                    "auteur": auteur,
                    "nombre de tokens": nb_tokens,
                    "nombre d'entités nommées": nb_entites,
                    "entités nommées": [{"texte": ent.text, "type": ent.label_} for ent in doc.ents],
                }

json_file_path = "/content/drive/MyDrive/resultat_lg_spacy.json"
with open(json_file_path, "w", encoding="utf-8") as json_file:
    json.dump(dic, json_file, ensure_ascii=False, indent=4)

print("\nNombre total de tokens par auteur :")
for auteur, nb_tokens in tokens_par_auteur.items():
    print(f"- {auteur}: {nb_tokens} tokens")

print("\nNombre total d'entités nommées par auteur :")
for auteur, nb_entites in entites_par_auteur.items():
    print(f"- {auteur}: {nb_entites} entités nommées")

total_tokens = sum(tokens_par_auteur.values())
total_entites = sum(entites_par_auteur.values())

print(f"\nNombre total de tokens dans tous les poèmes : {total_tokens}")
print(f"Nombre total d'entités nommées dans tous les poèmes : {total_entites}")

print(f"\nAnalyse terminée. Résultats enregistrés dans {json_file_path}.")
# Out:
# Auteurs:   0%|          | 0/10 [00:00<?, ?auteur/s]
# Poèmes de Appolinaire:   0%|          | 0/1 [00:00<?, ?poème/s]
# Poèmes de Appolinaire: 100%|██████████| 1/1 [00:06<00:00,  6.04s/poème]
# Auteurs:  10%|█         | 1/10 [00:06<00:55,  6.20s/auteur]
# Poèmes de Darbourville:   0%|          | 0/1 [00:00<?, ?poème/s]
# Poèmes de Darbourville: 100%|██████████| 1/1 [00:13<00:00, 13.44s/poème]
# Auteurs:  20%|██        | 2/10 [00:19<01:23, 10.47s/auteur]
# Poèmes de Desbordes:   0%|          | 0/1 [00:00<?, ?poème/s]
# Poèmes de Desbordes: 100%|██████████| 1/1 [00:07<00:00,  7.71s/poème]
# Auteurs:  30%|███       | 3/10 [00:27<01:04,  9.22s/auteur]
# Poèmes de Hugo:   0%|          | 0/1 [00:00<?, ?poème/s]
# Poèmes de Hugo: 100%|██████████| 1/1 [00:17<00:00, 17.12s/poème]
# Auteurs:  40%|████      | 4/10 [00:44<01:14, 12.34s/auteur]
# Poèmes de Loiseau:   0%|          | 0/1 [00:00<?, ?poème/s]
# Poèmes de Loiseau: 100%|██████████| 1/1 [00:04<00:00,  4.94s/poème]
# Auteurs:  50%|█████     | 5/10 [00:49<00:48,  9.68s/auteur]
# Poèmes de Noialles:   0%|          | 0/1 [00:00<?, ?poème/s]
# Poèmes de Noialles: 100%|██████████| 1/1 [00:03<00:00,  3.93s/poème]
# Auteurs:  60%|██████    | 6/10 [00:53<00:30,  7.73s/auteur]
# Poèmes de Rimbaud:   0%|          | 0/1 [00:00<?, ?poème/s]
# Poèmes de Rimbaud: 100%|██████████| 1/1 [00:05<00:00,  5.45s/poème]
# Auteurs:  70%|███████   | 7/10 [00:58<00:20,  6.99s/auteur]
# Poèmes de Sauvage:   0%|          | 0/1 [00:00<?, ?poème/s]
# Poèmes de Sauvage: 100%|██████████| 1/1 [00:06<00:00,  6.83s/poème]
# Auteurs:  80%|████████  | 8/10 [01:05<00:13,  6.94s/auteur]
# Poèmes de Verlaine:   0%|          | 0/1 [00:00<?, ?poème/s]
# Poèmes de Verlaine: 100%|██████████| 1/1 [00:03<00:00,  3.39s/poème]
# Auteurs:  90%|█████████ | 9/10 [01:09<00:05,  5.84s/auteur]
# Poèmes de Vivien:   0%|          | 0/1 [00:00<?, ?poème/s]
# Poèmes de Vivien: 100%|██████████| 1/1 [00:09<00:00,  9.15s/poème]
# Auteurs: 100%|██████████| 10/10 [01:18<00:00,  7.83s/auteur]
# Nombre total de tokens par auteur :
# - Appolinaire: 16834 tokens
# - Darbourville: 55910 tokens
# - Desbordes: 31130 tokens
# - Hugo: 66426 tokens
# - Loiseau: 20742 tokens
# - Noialles: 12901 tokens
# - Rimbaud: 20809 tokens
# - Sauvage: 20854 tokens
# - Verlaine: 14257 tokens
# - Vivien: 39110 tokens
#
# Nombre total d'entités nommées par auteur :
# - Appolinaire: 1171 entités nommées
# - Darbourville: 2712 entités nommées
# - Desbordes: 1936 entités nommées
# - Hugo: 3746 entités nommées
# - Loiseau: 1251 entités nommées
# - Noialles: 874 entités nommées
# - Rimbaud: 670 entités nommées
# - Sauvage: 1353 entités nommées
# - Verlaine: 1067 entités nommées
# - Vivien: 3382 entités nommées
#
# Nombre total de tokens dans tous les poèmes : 298973
# Nombre total d'entités nommées dans tous les poèmes : 18162
#
# Analyse terminée. Résultats enregistrés dans /content/drive/MyDrive/resultat_lg_spacy.json.

# %%
import spacy
from spacy import displacy
from IPython.core.display import display, HTML
import os

nlp = spacy.load("fr_core_news_lg")

auteur = "Rimbaud"
nom_fichier = "RIMBAUD_ILLUMINATIONS_ETC.txt"

file_path = os.path.join(base_path, auteur, nom_fichier)

with open(file_path, "r", encoding="utf-8") as f:
    texte = f.read()

portion = texte[:8000]

doc = nlp(portion)

html = displacy.render(doc, style="ent", jupyter=True)
display(HTML(html))
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Rappel de votre demande:<br><br><br>Format de téléchargement: :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texte
#
# Vues 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  à 169 sur 169<br><br>Nombre de pages: 169<br><br>Notice complète:<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Titre : les Illuminations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Une Saison en Enfer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# . Notice par
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paul Verlaine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# <br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Titre :
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Une Saison en Enfer
#
# Auteur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rimbaud
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arthur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (1854-1891). Auteur du texte<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Éditeur : L. Vanier
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# )<br><br>Date d'édition :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1892
#
# Contributeur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Verlaine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (1844-1896).
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Préfacier
#
# Notice du catalogue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     http://catalogue.bnf.fr/ark:/12148/cb35285747v
#
# Type
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  : monographie imprimée<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Langue : français
#
# Langue : Français
#
# Format
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VIII-151
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  p. ; 19 cm<br><br>Format : Nombre total de vues : 169<br><br>Description : Avec mode texte<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Droits : Consultable
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ligne
#
# Droits : Public domain
#
# Identifiant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  : ark:/12148/
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     btv1b8618404b
#
# Source :
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bibliothèque nationale de France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , département
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Réserve des livres rares
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , RESP-Z-2180<br><br>Conservation numérique :
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bibliothèque nationale de France
#
# Date de mise en ligne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  : 11/07/2011<br><br>Le texte affiché peut comporter un certain nombre d'erreurs. En effet, le mode texte de ce document a été généré de façon automatique par un programme de reconnaissance optique de caractères (
# <mark

# %%
import spacy
from spacy import displacy
from IPython.core.display import display, HTML
import os


nlp = spacy.load("fr_core_news_lg")

auteur = "Verlaine"
nom_fichier = "VERLAINE_Sagesse.txt"

file_path = os.path.join(base_path, auteur, nom_fichier)

with open(file_path, "r", encoding="utf-8") as f:
    texte = f.read()

portion = texte[:8000]  # Porção do texto para visualização

doc = nlp(portion)

html = displacy.render(doc, style="ent", jupyter=True)
display(HTML(html))
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Rappel de votre demande:<br><br><br>Format de téléchargement: :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texte
#
# Vues 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  à 167 sur 167<br><br>Nombre de pages: 167<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Notice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  complète:<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Titre :
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Sagesse (3e édition revue et corrigée) /
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paul Verlaine
#
# Auteur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Verlaine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (1844-1896). Auteur du texte<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Éditeur : L. Vanier
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# )<br><br>Date d'édition :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1893
#
# Notice d'oeuvre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  : http://catalogue.bnf.fr/ark:/12148/cb11954649v<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Notice du catalogue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     http://catalogue.bnf.fr/ark:/12148/cb437416104
#
# Type
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  : monographie imprimée<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Langue : français
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Langue :
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Français
#
# Format
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  : 1 vol. (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     II-133
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  p.) ; in-18<br><br>Format : Nombre total de vues : 167<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Description : [
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sagesse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  (français)]<br><br>Description : Contient une table des matières<br><br>Description : Avec mode texte<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Droits : Consultable
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ligne
#
# Droits : Public domain
#
# Identifiant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  : ark:/12148/bpt6k6479939v<br><br>Source :
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bibliothèque nationale de France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , département
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Littérature et art
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , 8-YE-3265<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Conservation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  numérique :
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bibliothèque nationale de France
#
# Date de mise en ligne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  : 16/04/2013<br><br>Le texte affiché peut comporter un certain nombre d'erreurs. En effet, le mode texte de ce document a été généré de façon aut
